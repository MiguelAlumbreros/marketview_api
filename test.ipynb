# %%
import pandas as pd

# %%
df = pd.read_csv("output.csv")
df[(df['strip'] == 'month')
   &(df['commodity'] == 'gas')
   &(df['product'] == 'PVB/TTF')
   ].description.unique()

# df.strip.unique()
# Out:
# <StringArray>
# ['PVB/TTF front 1 month', 'PVB/TTF front 2 month', 'PVB/TTF front 3 month']
# Length: 3, dtype: str
